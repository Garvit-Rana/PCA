# %%
from sklearn import datasets
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import time
from sklearn import ensemble
from sklearn.metrics import classification_report,confusion_matrix

# %%
lfw=datasets.fetch_lfw_people(min_faces_per_person=100,resize=0.4)
# Out:
# ...
# C:\Users\Garvit\Anaconda3\lib\site-packages\sklearn\datasets\lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# C:\Users\Garvit\Anaconda3\lib\site-packages\sklearn\datasets\lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   face = imresize(face, resize)
# C:\Users\Garvit\Anaconda3\lib\site-packages\sklearn\datasets\lfw.py:184: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   img = imread(file_path)
# C:\Users\Garvit\Anaconda3\lib\site-packages\sklearn\datasets\lfw.py:193: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# ...

# %%
lfw.keys()
# Out:
# dict_keys(['data', 'images', 'target', 'target_names', 'DESCR'])

# %%
lfw.data.shape
# Out:
# (1140, 1850)

# %%
lfw.images.shape
# Out:
# (1140, 50, 37)

# %%
pca=PCA()
x=lfw.data
y=lfw.target
xtrain,xtest,ytrain,ytest=train_test_split(x,y)

# %%
pca.fit(xtrain)
pca.components_.shape
# Out:
# (855, 1850)

# %%
fig=plt.figure(figsize=(8,8))
for i in range(64):
    ax=fig.add_subplot(8,8,i+1)
    ax.imshow(lfw.images[i],cmap=plt.cm.bone)
plt.show()

# %%
total=pca.explained_variance_.sum()
curr=0
k=0
while curr/total<0.99:
    curr+=pca.explained_variance_[k]
    k+=1
k
# Out:
# 317

# %%
pca=PCA(n_components=k,whiten=True)
x_train=pca.fit_transform(xtrain)

# %%
x_app=pca.inverse_transform(x_train)
x_app.shape
# Out:
# (855, 1850)

# %%
x_app=x_app.reshape((855,50,37))
x_app.shape
# Out:
# (855, 50, 37)

# %%
fig=plt.figure(figsize=(8,8))
for i in range(64):
    ax=fig.add_subplot(8,8,i+1)
    ax.imshow(x_app[i],cmap=plt.cm.bone)
plt.show()

# %%
eigen=pca.components_
eigen.shape
# Out:
# (317, 1850)

# %%
eigenface=eigen.reshape((317,50,37))
fig=plt.figure(figsize=(8,8))
for i in range(64):
    ax=fig.add_subplot(8,8,i+1)
    ax.imshow(eigenface[i], cmap=plt.cm.bone)

# %%
x_test=pca.transform(xtest)

# %%
rf=ensemble.RandomForestClassifier()
st=time.time()
rf.fit(xtrain,ytrain)
en=time.time()
print(en-st)
y_pre=rf.predict(xtest)
print(classification_report(ytest,y_pre))
print(confusion_matrix(ytest,y_pre))
# Out:
# 0.8796262741088867
#              precision    recall  f1-score   support
#
#           0       0.55      0.67      0.60        48
#           1       0.35      0.17      0.23        35
#           2       0.62      0.87      0.72       134
#           3       0.62      0.19      0.29        27
#           4       0.64      0.22      0.33        41
#
# avg / total       0.58      0.59      0.54       285
#
# [[ 32   3  13   0   0]
#  [  7   6  20   1   1]
#  [ 11   3 116   1   3]
#  [  2   2  17   5   1]
#  [  6   3  22   1   9]]

# %%
rf=ensemble.RandomForestClassifier()
st=time.time()
rf.fit(x_train,ytrain)
en=time.time()
print(en-st)
y_pre=rf.predict(x_test)
print(classification_report(ytest,y_pre))
print(confusion_matrix(ytest,y_pre))
# Out:
# 0.44130563735961914
#              precision    recall  f1-score   support
#
#           0       0.24      0.42      0.31        48
#           1       0.19      0.09      0.12        35
#           2       0.59      0.74      0.66       134
#           3       0.30      0.11      0.16        27
#           4       0.56      0.12      0.20        41
#
# avg / total       0.45      0.46      0.42       285
#
# [[20  2 22  1  3]
#  [16  3 14  2  0]
#  [26  7 99  1  1]
#  [ 6  1 17  3  0]
#  [14  3 16  3  5]]
